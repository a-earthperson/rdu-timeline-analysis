# %% [markdown]
# # Raleigh/Durham FO AOS Timeline — Reproducible Analysis
#
# (See `scripts/run_analysis.py` for the full end-to-end runner.)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from rdu_timeline_analysis.io import load_dataset_csv

TODAY = pd.Timestamp("2026-02-04")
df = load_dataset_csv(csv_path="data/canonical/rdu_timeline_data.csv")
df["age_days_since_receipt"] = (TODAY - df["i-485 receipt date_dt"]).dt.days
df["age_days_since_interview"] = (TODAY - df["interview date_dt"]).dt.days
df.head()

# %% [markdown]
# This notebook is intentionally concise; `scripts/run_analysis.py` generates the full artifact set.

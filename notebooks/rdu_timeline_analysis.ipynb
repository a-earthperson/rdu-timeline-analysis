# %% [markdown]
# # Raleigh/Durham FO AOS Timeline - Notebook\n
# \n
# Production artifacts are generated by `scripts/run_analysis.py`.

# %%
import pandas as pd\n
\n
df = pd.read_csv("../data/canonical/rdu_timeline_data.csv")\n
df.head()
